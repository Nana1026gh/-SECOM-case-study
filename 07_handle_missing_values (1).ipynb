# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Handling missing values

# %%
df = pd.DataFrame({'some_column': [1, np.nan, np.nan, 2, 3, 1, 3, np.nan, 3], 
                   'another_column': [10, np.nan, np.nan, 20, 30, 10, 30, np.nan, 30], 
                   'target': ['A','A', 'B','B','B','B', 'C','C','C']})

# %%
df
# Out:
#    some_column  another_column target
# 0          1.0            10.0      A
# 1          NaN             NaN      A
# 2          NaN             NaN      B
# 3          2.0            20.0      B
# 4          3.0            30.0      B
# 5          1.0            10.0      B
# 6          3.0            30.0      C
# 7          NaN             NaN      C
# 8          3.0            30.0      C

# %% [markdown]
# ### 1. Drop all missing values

# %%
df.dropna()
# Out:
#    some_column  another_column target
# 0          1.0            10.0      A
# 3          2.0            20.0      B
# 4          3.0            30.0      B
# 5          1.0            10.0      B
# 6          3.0            30.0      C
# 8          3.0            30.0      C

# %% [markdown]
# we would lose one third of the data

# %% [markdown]
# ### 2. Fill NAs with certain values (static)

# %%
df.fillna(value=99)
# Out:
#    some_column  another_column target
# 0          1.0            10.0      A
# 1         99.0            99.0      A
# 2         99.0            99.0      B
# 3          2.0            20.0      B
# 4          3.0            30.0      B
# 5          1.0            10.0      B
# 6          3.0            30.0      C
# 7         99.0            99.0      C
# 8          3.0            30.0      C

# %% [markdown]
# ### 3. We can use some average to fill the NAs

# %%
#for indiviual columns
df['some_column'].fillna(value=df['some_column'].mean(), inplace=True)

# %%
df
# Out:
#    some_column  another_column target
# 0     1.000000            10.0      A
# 1     2.166667             NaN      A
# 2     2.166667             NaN      B
# 3     2.000000            20.0      B
# 4     3.000000            30.0      B
# 5     1.000000            10.0      B
# 6     3.000000            30.0      C
# 7     2.166667             NaN      C
# 8     3.000000            30.0      C

# %% [markdown]
# for the entire dataframe

# %%
df = pd.DataFrame({'some_column': [1, np.nan, np.nan, 2, 3, 1, 3, np.nan, 3], 
                   'another_column': [10, np.nan, np.nan, 20, 30, 10, 30, np.nan, 30], 
                   'target': ['A','A', 'B','B','B','B', 'C','C','C']})

# %%
df.fillna(value = df.mean())
# Out:
#    some_column  another_column target
# 0     1.000000       10.000000      A
# 1     2.166667       21.666667      A
# 2     2.166667       21.666667      B
# 3     2.000000       20.000000      B
# 4     3.000000       30.000000      B
# 5     1.000000       10.000000      B
# 6     3.000000       30.000000      C
# 7     2.166667       21.666667      C
# 8     3.000000       30.000000      C

# %% [markdown]
# ### 4. using an average according to the target variable

# %%
df.groupby('target').fillna(value=df.mean())
# Out:
#           some_column  another_column
# target
# A      0     1.000000       10.000000
#        1     2.166667       21.666667
# B      2     2.166667       21.666667
#        3     2.000000       20.000000
#        4     3.000000       30.000000
#        5     1.000000       10.000000
# C      6     3.000000       30.000000
#        7     2.166667       21.666667
#        8     3.000000       30.000000

# %% [markdown]
# does not work yet

# %%
df.groupby('target').apply(lambda x: x.fillna(x.mean()))
# Out:
#           some_column  another_column target
# target
# A      0          1.0            10.0      A
#        1          1.0            10.0      A
# B      2          2.0            20.0      B
#        3          2.0            20.0      B
#        4          3.0            30.0      B
#        5          1.0            10.0      B
# C      6          3.0            30.0      C
#        7          3.0            30.0      C
#        8          3.0            30.0      C

# %%
df.groupby('target').transform(lambda x: x.fillna(x.mean()))
# Out:
#    some_column  another_column
# 0          1.0            10.0
# 1          1.0            10.0
# 2          2.0            20.0
# 3          2.0            20.0
# 4          3.0            30.0
# 5          1.0            10.0
# 6          3.0            30.0
# 7          3.0            30.0
# 8          3.0            30.0

# %%
df[['some_column', 'another_column']] = df.groupby('target').transform(lambda x: x.fillna(x.mean()))

# %%
df
# Out:
#    some_column  another_column target
# 0          1.0            10.0      A
# 1          1.0            10.0      A
# 2          2.0            20.0      B
# 3          2.0            20.0      B
# 4          3.0            30.0      B
# 5          1.0            10.0      B
# 6          3.0            30.0      C
# 7          3.0            30.0      C
# 8          3.0            30.0      C

# %% [markdown]
# transform returns a Series which has the same length as the input (calculations are the same as with apply)

# %% [markdown]
# ### 5. replace missing with the last available value (e. g. timeseries)

# %%
df = pd.DataFrame({'some_column': [1, np.nan, np.nan, 2, 3, 1, 3, np.nan, 3],
'another_column': [10, np.nan, np.nan, 20, 30, 10, 30, np.nan, 30],
'target': ['A','A', 'B','B','B','B', 'C','C','C']})

# %%
df.fillna(method='ffill')
# Out:
#    some_column  another_column target
# 0          1.0            10.0      A
# 1          1.0            10.0      A
# 2          1.0            10.0      B
# 3          2.0            20.0      B
# 4          3.0            30.0      B
# 5          1.0            10.0      B
# 6          3.0            30.0      C
# 7          3.0            30.0      C
# 8          3.0            30.0      C
